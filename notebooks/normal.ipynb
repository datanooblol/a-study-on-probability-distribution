# %%
from scipy.stats import norm
import numpy as np

# %% [markdown]
# ## PDF
# $$
# f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x-\mu)^{2}}{2\sigma^{2}}}
# $$

# %%
mu, sigma = 0, 1   # standard normal
dist = norm(loc=mu, scale=sigma)

# %%
# 1 std
dist.cdf(1) - dist.cdf(-1)
# Out:
# np.float64(0.6826894921370859)

# %%
for i in range(1,4,1):
    area = dist.cdf(i) - dist.cdf(-i)
    print(area)
# Out:
# 0.6826894921370859
# 0.9544997361036416
# 0.9973002039367398

# %%
dist.cdf(1), dist.pdf(1)
# Out:
# (np.float64(0.8413447460685429), np.float64(0.24197072451914337))

# %%
1-dist.cdf(1)
# Out:
# np.float64(0.15865525393145707)

# %%
# if we use the function, no need to convert it into z_score
mu, sigma = 100, 15
k = 130
dist = norm(loc=mu, scale=sigma)

# %%
# left side, right side
dist.cdf(k), 1-dist.cdf(k)
# Out:
# (np.float64(0.9772498680518208), np.float64(0.02275013194817921))

# %%
mu-(2*sigma), mu+(2*sigma)
# Out:
# (70, 130)

# %%
dist.cdf(130)-dist.cdf(70)
# Out:
# np.float64(0.9544997361036416)
